# %% [markdown]
# # 1. 인구 피라미드

# %% [markdown]
# ## 남자 데이터 정의

# %%
import pandas as pd
file_name = '201511_연령별인구현황.xlsx'
df_m = pd.read_excel(file_name, skiprows=3, index_col=1, usecols='B,E:O')
df_m.head(3)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               행정기관     10~19세     20~29세     30~39세     40~49세     50~59세  \
# 0~9세
# 2,364,703     전국    2,995,795  3,522,588  3,925,714  4,512,070  4,187,825
# 402,283    서울특별시      513,122    724,322    840,452    851,908    774,077
# 137,231    부산광역시      182,646    240,802    252,923    283,390    300,147
#
#               60~69세     70~79세   80~89세  90~99세 100세 이상
# 0~9세
# 2,364,703  2,445,917  1,368,651  386,936  38,372   3,774
# 402,283      490,826    266,975   65,483   7,742   1,292
# 137,231      206,195    105,824   24,727   2,078     316

# %%
df_m.iloc[0] = df_m.iloc[0].str.replace(',','').astype(int) # 1,521,194->1521194
df_m.iloc[0]
# Out:
# 0~9세       2364703
# 10~19세     2995795
# 20~29세     3522588
# 30~39세     3925714
# 40~49세     4512070
# 50~59세     4187825
# 60~69세     2445917
# 70~79세     1368651
# 80~89세      386936
# 90~99세       38372
# 100세 이상       3774
# Name: 전국  , dtype: object

# %% [markdown]
# ## 여자 데이터 정의

# %%
df_w = pd.read_excel(file_name, skiprows=3, index_col='행정기관',usecols='B,R:AB')
df_w.head(3)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             0~9세.1   10~19세.1   20~29세.1   30~39세.1   40~49세.1   50~59세.1  \
# 행정기관
# 전국       2,233,783  2,749,143  3,168,722  3,759,883  4,359,472  4,117,003
# 서울특별시      381,679    478,711    725,439    833,346    854,229    814,016
# 부산광역시      129,560    164,966    215,712    242,195    286,160    319,678
#
#           60~69세.1   70~79세.1 80~89세.1 90~99세.1 100세 이상.1
# 행정기관
# 전국       2,593,476  1,815,081  827,232  126,893    12,366
# 서울특별시      542,247    316,075  125,684   21,960     3,729
# 부산광역시      223,764    134,269   53,694    7,398     1,167

# %%
df_m.columns
# Out:
# Index(['0~9세', '10~19세', '20~29세', '30~39세', '40~49세', '50~59세', '60~69세',
#        '70~79세', '80~89세', '90~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns
# Out:
# Index(['0~9세.1', '10~19세.1', '20~29세.1', '30~39세.1', '40~49세.1', '50~59세.1',
#        '60~69세.1', '70~79세.1', '80~89세.1', '90~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
df_w.columns = df_m.columns #컬럼명 통일

# %%
df_w.columns
# Out:
# Index(['0~9세', '10~19세', '20~29세', '30~39세', '40~49세', '50~59세', '60~69세',
#        '70~79세', '80~89세', '90~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.iloc[0] = df_w.iloc[0].str.replace(',','').astype(int) # 1,521,194->1521194
df_w.iloc[0]
# Out:
# 0~9세       2233783
# 10~19세     2749143
# 20~29세     3168722
# 30~39세     3759883
# 40~49세     4359472
# 50~59세     4117003
# 60~69세     2593476
# 70~79세     1815081
# 80~89세      827232
# 90~99세      126893
# 100세 이상      12366
# Name: 전국  , dtype: object

# %% [markdown]
# ## 데이터 시각화

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
#matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(10,7))
plt.barh(df_m.columns, -df_m.iloc[0]//1000) #단위 : 천명
plt.barh(df_w.columns, df_w.iloc[0]//1000)
plt.title('2015년 11월 대한민국 인구 피라미드')
plt.savefig('2015년 11월 인구피라미드.png',dpi=100)
plt.show()
